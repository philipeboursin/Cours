# %% [markdown]
# **Exercice 1**
#
# Rappelons que si $G$ est une base de Groebner marquée $\{(g_i, \alpha_i)\}$, où $g_i = x^{\alpha_i} + \sum_{\beta} c_{i, \beta}x^\beta$, alors l'adhérence du cone ouvert associé dans l'éventail de Groebner est donné par $\overline{C}_G = \{w \in \mathbb{R}^n_+ \mid \alpha_i \cdot w \geq \beta \cdot w,\, \forall \beta$ tq $c_{i, \beta} \neq 0\}$.

# %% [markdown]
# **1)**

# %%
A.<x,y> = PolynomialRing(QQ, order = 'lex')
I = A.ideal(x^2 + y^2 - 1, x + 2*y)
# Out:
# For 2-D fan rendering the polynomial ring must have 3 variables (or more, which are ignored).
# NotImplementedErrorTraceback (most recent call last)
# <ipython-input-1-641bc36f35d6> in <module>()
#       2 I = A.ideal(x**Integer(2) + y**Integer(2) - Integer(1), x + Integer(2)*y)
#       3 gf = I.groebner_fan()
# ----> 4 gf.render()
#
# /usr/lib/python2.7/dist-packages/sage/rings/polynomial/groebner_fan.pyc in render(self, file, larger, shift, rgbcolor, polyfill, scale_colors)
#    1276         if S.ngens() < 3:
#    1277             print("For 2-D fan rendering the polynomial ring must have 3 variables (or more, which are ignored).")
# -> 1278             raise NotImplementedError
#    1279         cmd = 'render'
#    1280         if shift:
#
# NotImplementedError:

# %% [markdown]
# **2)**

# %%
I = A.ideal(x^3 - y, x + y^3 + 1)
G = I.groebner_basis()
print(G)
B = A.change_ring(names = 'y,x')
H = I.change_ring(B).groebner_basis()
print(H)
B = A.change_ring(names = 'x,y', order = 'degrevlex')
H = I.change_ring(B).groebner_basis()
print(H)
# Out:
# [x + y^3 + 1, y^9 + 3*y^6 + 3*y^3 + y + 1]
# [y - x^3, x^9 + x + 1]
# [x^3 - y, y^3 + x + 1]

# %% [markdown]
# **3)**

# %%
A.<x,y,z> = PolynomialRing(QQ, order = 'lex')
I = A.ideal(y^2 - x^2, z - y^4)
G = I.groebner_basis()
print(G)
B = A.change_ring(names = 'z,y,x')
H = I.change_ring(B).groebner_basis()
print(H)
B = A.change_ring(names = 'y,x,z')
H = I.change_ring(B).groebner_basis()
print(H)
B = A.change_ring(names = 'z,x,y')
H = I.change_ring(B).groebner_basis()
print(H)
# Out:
# [x^2 - y^2, y^4 - z]
# [z - x^4, y^2 - x^2]
# [y^2 - x^2, x^4 - z]
# [z - y^4, x^2 - y^2]

# %% [markdown]
# **4)**

# %%
I = A.ideal(y - x^2, z - x^3)
G = I.groebner_basis()
print(G)
B = A.change_ring(names = 'z,y,x')
H = I.change_ring(B).groebner_basis()
print(H)
B = A.change_ring(names = 'y,x,z')
H = I.change_ring(B).groebner_basis()
print(H)
m = matrix(3, [1,1,0,0,1,0,0,0,1])
print(m)
T = TermOrder(m)
B = A.change_ring(order = T)
H = I.change_ring(B).groebner_basis()
print(H)

gf = I.groebner_fan()
gf.render()
# Out:
# [x^2 - y, x*y - z, x*z - y^2, y^3 - z^2]
# [z - x^3, y - x^2]
# [y - x^2, x^3 - z]
# [1 1 0]
# [0 1 0]
# [0 0 1]
# [y^2 - x*z, x*y - z, x^2 - y]
# Graphics object consisting of 12 graphics primitives

# %%
A.<x,y,z,t> = PolynomialRing(QQ)
I = A.ideal(y - x^2, z - x^3, t - x)
g = I.groebner_fan()
g.render3d()
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-44-014d6afd7085> in <module>()
#       2 I = A.ideal(y - x**Integer(2), z - x**Integer(3), t - x)
#       3 g = I.groebner_fan()
# ----> 4 g.render3d(viewer = 'taychon')
#
# TypeError: render3d() got an unexpected keyword argument 'viewer'
